# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
with open('./clima_canada.csv','r')as file1:
    df = pd.read_csv(file1)
    df = pd.DataFrame(data=df)

# %%
df
# Out:
#        Temperatura  Humedad  Viento  Precipitacion(%)        Nublado  \
# 0               14       73     9.5                82  partly cloudy
# 1               39       96     8.5                71  partly cloudy
# 2               30       64     7.0                16          clear
# 3               38       83     1.5                82          clear
# 4               27       74    17.0                66       overcast
# ...            ...      ...     ...               ...            ...
# 13195           10       74    14.5                71       overcast
# 13196           -1       76     3.5                23         cloudy
# 13197           30       77     5.5                28       overcast
# 13198            3       76    10.0                94       overcast
# 13199           -5       38     0.0                92       overcast
#
#        Nublado2  Presion  UV  Season  Season_id  Visibilidad  Location  \
# ...

# %%
lr = LinearRegression()
z = df[['Temperatura', 'Humedad', 'Viento', 'Precipitacion(%)']]
y = df['Nublado2']
lr.fit(z,y)
# Out:
# LinearRegression()

# %%
###### CODIGO PARA PREDECIR EL ESTADO DEL TIEMPO A PARTIR DE ALGUNAS VARIABLES

# %%
t = 16 #temperatura
v = 71 #velocidad del viento
h = 9.0 #humedad
p = 80 #precipitacion en %
# nuevo dataframe
d = {'Temperatura':[t],'Humedad':[h], 'Viento':[v],  'Precipitacion(%)':[p]}
x_valors = pd.DataFrame(data=d)
x_valors
# Out:
#    Temperatura  Humedad  Viento  Precipitacion(%)
# 0           16      9.0      71                80

# %%
Yhat = lr.predict(x_valors)
valor_Z_Yhat = int(Yhat)
# Out:
# C:\Users\ALEX\AppData\Local\Temp\ipykernel_6520\1992595543.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   valor_Z_Yhat = int(Yhat)

# %%
if valor_Z_Yhat == 100:
    print('clear-->100')
elif valor_Z_Yhat ==101:
    print('cloudy-->101')
elif valor_Z_Yhat ==102:
    print('overcast-->102')
else:
    print('partly cloudy-->103')
# Out:
# overcast-->102
