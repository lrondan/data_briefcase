# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
with open('./UFOs_coord.csv','r')as file:
    archivo = pd.read_csv(file)
    df1 = pd.DataFrame(data=archivo)

# %%
country = df1['Country']
Shape = df1['Shape']

# %%
a = Shape.value_counts()
b = country.value_counts()

# %%
plt.plot(a, label='Shape')
plt.legend()
