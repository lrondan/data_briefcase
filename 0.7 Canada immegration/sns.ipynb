# %%
#Modelo de prediccion de migracion en canada para el ano proximo por continentes.

# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
with open('./new_train.csv','r')as file:
    archi = pd.read_csv(file)
    df = pd.DataFrame(data=archi)

# %%
lm = LinearRegression()

# %%
#seleccion de valores
Cont = df['Etiquetas de fila']
v00 = df[['Suma de 2000','Suma de 2002','Suma de 2004','Suma de 2006','Suma de 2008','Suma de 2010','Suma de 2012']]

v_comparable_08 = df[['Suma de 2001','Suma de 2003','Suma de 2005','Suma de 2007','Suma de 2009','Suma de 2011']]
v_comparable_13 = df['Suma de 2013']

# %%
lm.fit(v00,v_comparable_08)
# Out:
# LinearRegression()

# %%
Yhat = lm.predict(v00)

# %%
ydata = pd.DataFrame(data=Yhat)
predict0 = ydata[0]
predict1 = ydata[1]
predict2 = ydata[2]
predict3 = ydata[3]
predict4 = ydata[4]
predict5 = ydata[5]
media = ydata.median(axis=1)

# %%
sns.distplot(predict0, color='b')
sns.distplot(predict1, color='b')
sns.distplot(predict2, color='b')
sns.distplot(predict3, color='b')
sns.distplot(predict4, color='b')
sns.distplot(predict5, color='b')
sns.distplot(media, color='r')
# Out:
# C:\Users\ALEX\AppData\Local\Temp\ipykernel_11260\1538815632.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(predict0, color='b')
# C:\Users\ALEX\AppData\Local\Temp\ipykernel_11260\1538815632.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(media, color='r')
sns.distplot(v_comparable_13, color='b')
# Out:
# C:\Users\ALEX\AppData\Local\Temp\ipykernel_11260\4220181913.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(media, color='r')
# C:\Users\ALEX\AppData\Local\Temp\ipykernel_11260\4220181913.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#prediccion para el ano 2014

# %%
lm.fit(Yhat, v00)
# Out:
# LinearRegression()

# %%
Yast = lm.predict(Yhat)

# %%
sns.distplot(Yast, color='r')
sns.distplot(Yhat, color='b')
sns.distplot(media, color='g')
# Out:
# C:\Users\ALEX\AppData\Local\Temp\ipykernel_11260\585383305.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Yast, color='r')
# C:\Users\ALEX\AppData\Local\Temp\ipykernel_11260\585383305.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Yhat, color='b')
# ...

# %%
n_predict = pd.DataFrame(data=Yast)
gurad=n_predict.rename(index={0:'Africa', 1:'Asia', 2:'Eur', 3:'LATAM', 4:'NortAme',5:'Ocean',6:'Total'},columns={0:'2014', 1:'2015', 2:'2016', 3:'2017', 4:'2018',5:'2019',6:'2020'})
print(gurad)
# Out:
#              2014      2015      2016      2017      2018      2019      2020
# Africa    20346.0   22710.0   28192.0   29188.0   29890.0   40892.0   38083.0
# Asia     134544.0  137653.0  134850.0  149054.0  139894.0  163845.0  152218.0
# Eur       38215.0   36798.0   38082.0   33053.0   34692.0   33425.0   29177.0
# LATAM     16898.0   19317.0   22181.0   24676.0   26547.0   28818.0   27173.0
# NortAme    5433.0    4948.0    6990.0    9613.0   10190.0    8142.0    7892.0
# Ocean      1276.0    1685.0    1788.0    1473.0    1834.0    1834.0    1679.0
# Total    216712.0  223111.0  232083.0  247057.0  243047.0  276956.0  256222.0

# %%
gurad.to_csv('./prediccion_proximos_anos.csv')
